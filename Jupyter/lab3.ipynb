# %%
import requests
from bs4 import BeautifulSoup
import re

req = requests.get('http://media.daum.net/ranking/popular/') #utf-8 이다!
html = req.content
html = html.decode('utf-8')
bs = BeautifulSoup(html, 'html.parser')


titles = bs.select('#mArticle > div.rank_news > ul.list_news2 > li > div.cont_thumb > strong > a')
presses = bs.select('#mArticle > div.rank_news > ul.list_news2 > li > div.cont_thumb > strong > span')
news_titles = []
news_presses = [] 



for dom in presses:
    content=re.sub("[\n\t]", '', content)
    movie_review.append(content)
    
    news_presses.append(dom.text)
    
    
for dom in titles:
    news = dom.contents[0]
    news=re.sub(",", ' ', news)
    news_titles.append(news)
    

    
print(news_titles)
print(news_presses)


# 한 행씩 맞춰서 출력
allnewslength = len(news_presses)   
for i in range(allnewslength):
    print("newstitle : " + news_titles[i])
    print("newscomname : " + news_presses[i])

    
# csv 파일로 저장
with open('output/news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitle,newscomname\n')  
    for i in range(len(news_presses)):
        f.write(news_titles[i]+","+news_presses[i]+'\n')
# Out:
# ["시장에서 산 고둥서 나온 돌 알고보니 수천만원 '희귀 진주'", '노원구 아파트서 세 모녀 숨진채 발견..용의자는 자해', '"\'구미 3세 사망 여아\' 나올 수 없는 혈액형  둘 다 외도?" [황출새]', '[제보는Y] "살려달라" 비명에 신고한 배송기사..피 흘리던 종업원 구해', '\'건강 이상설\' 돈 79세 바이든..기자회견 중 "어디까지 말했나"', '베이비박스에 아이 넣고 돌아서는 순간  일어나는 일', '월 15만원에 깨끗한 집 빌려주자  동네 소원이 이뤄졌다 [월간 옥이네]', '"혹시 당근이세요?"..\'만남의 광장\'으로  변신한 중고거래앱', '\'구미 3세 여아\' 친모·큰딸 모두 외도?.."나올 수 없는 혈액형"', '[사건의 재구성]"미안  형편 어려워.." 혼수상태 아내 호흡기 뗀 남편', '오세훈 "중증치매 환자..대통령에게 그 정도 말도 못하나"', "'혈액형에서 단서 찾았다'..구미 여아 사건 실마리 풀리나", '"전생에 우린 연인 관계였다"..친딸 성폭행한 아빠 \'징역 13년\'', '"美인도·태평양사령부  日요구에 \'동해\' 표기 정정"<교도>', '[시선집중] 이상돈 "안철수 도움보다 피곤하게 할 거라는 걸 김종인도 아는 것"', '입원중인 이재용 부회장  1인실서 4명의 순환감시..국가가 부담하나', '석달 밀린 월급 달랬더니 기름 뿌린 9만 1500개의 동전 집 앞에', '[특파원 시선] 1988년 서울올림픽 엠블럼이 이탈리아 주유소에?', "[단독] 박형준 정무수석 시절 국정원 '사찰 문건' 원문 공개 ②", '"순두부찌개 맛없어 밥값 못준다" 난동..벌금 800만원', '바이든  中에 재차 경고.."내 눈앞에서 세계 최강국 되는 일 없을 것"', '대통령 백신 바꿔치기 의혹 "청맹과니나 하는 짓"', "'바닥 민심'에 안 꽂히는 오세훈 내곡동 총공세  왜?", '삼성중  컨선 20척 2조8천억원에 수주..단일계약으론 세계 최대', '"백반 한 끼 1000원 식당주인..지갑은 적자  마음은 부자"', '호주  대중국 건초 수출 제동..부메랑 맞은 중국', '정 총리 "현행 거리두기 2주 연장..5인 모임 금지도 유지"', '"서당 보낸 딸  악마보다 더한 폭행·성적 고문에 엉망됐다..제발"', "부산어시장에 등장한 '바다의 로또' 참다랑어 2천마리", '김종인 "윤석열  별의순간 포착..잘 준비하면 진짜 별 딴다"', '"합석 거부하자 음식 기다리던 중 쫓겨났습니다" [지금e슈]', '\'생파 5번\' 남양주시장에.."월급이 부끄럽다" 대신 사과한 공무원', '"미혼동료가 유부남과 호텔 들어가더라"..허위사실 40대 남성 집유', '평균 연봉 1억원 시대?..웃지못하는 은행권', '"DNA 나왔으면 할 수 없네요" 이춘재도 DNA로 잡았다', '오세훈이 박영선 앞서자 親文 "요즘 20대는 철이 없어서.."', "구미 친모와 큰딸 '바꿔치기' 공모했나..또 반전", '미인대회 출전 미스 미얀마  국제사회에 "우리 국민 도와주세요"', '아시나요? 동백꽃은 세 번 핍니다', '국민의힘 "안철수 개별입당" vs 국민의당 "합당"..물밑 \'기싸움\'', '노원구 아파트서 세 모녀 피살.. 20대 피의자 현장서 자해', '"기부받은 10억 다시 기부"..美 증오범죄 피해 할머니의 결심', "'생후 20일 아기를 거꾸로'.. 산후도우미 학대 폭로글 등장", "[영상] '여기 도와주세요!' 트럭 세워 주인 살린 반려견", "식약처  수입 프로바이오틱스 제품 4건 '부적합'..회수 조치", '유령도시로 변한 산티아고..칠레  초강력 코로나 봉쇄령 발동', '[현장영상] "2주간 현행 거리두기 단계·5인 이상 모임 금지 유지"', '군에 끌려간 12만명이 굶어죽고 얼어죽었다', '文 34% 최저치 경신  40대도 흔들..민주당 32% 동반 최저(종합)', '[술 취한 의사들 ①] "점심에 소주 반 병  응급실서 와인 진료"..병원 특유의 폐쇄성으로 그저 \'쉬쉬\'']
# ['서울신문', '뉴시스', 'YTN', 'YTN', '머니투데이', '오마이뉴스', '오마이뉴스', '뉴스1', '머니투데이', '뉴스1', '연합뉴스', 'KBS', '이데일리', '연합뉴스', 'MBC', '이데일리', '서울신문', '연합뉴스', 'MBC', '뉴시스', '뉴스1', '미디어오늘', '한국일보', '연합뉴스', '노컷뉴스', '아시아경제', '뉴시스', '머니투데이', '연합뉴스', '연합뉴스', '데일리안', '머니투데이', '뉴스1', '디지털타임스', '머니투데이', '조선일보', '노컷뉴스', '연합뉴스', '오마이뉴스', '헤럴드경제', '조선일보', '서울신문', '파이낸셜뉴스', 'SBS', '연합뉴스', '서울신문', 'YTN', '프레시안', '뉴스1', '데일리안']
# newstitle : 시장에서 산 고둥서 나온 돌 알고보니 수천만원 '희귀 진주'
# newscomname : 서울신문
# newstitle : 노원구 아파트서 세 모녀 숨진채 발견..용의자는 자해
# newscomname : 뉴시스
# newstitle : "'구미 3세 사망 여아' 나올 수 없는 혈액형  둘 다 외도?" [황출새]
# newscomname : YTN
# newstitle : [제보는Y] "살려달라" 비명에 신고한 배송기사..피 흘리던 종업원 구해
# newscomname : YTN
# newstitle : '건강 이상설' 돈 79세 바이든..기자회견 중 "어디까지 말했나"
# newscomname : 머니투데이
# newstitle : 베이비박스에 아이 넣고 돌아서는 순간  일어나는 일
# newscomname : 오마이뉴스
# newstitle : 월 15만원에 깨끗한 집 빌려주자  동네 소원이 이뤄졌다 [월간 옥이네]
# newscomname : 오마이뉴스
# newstitle : "혹시 당근이세요?"..'만남의 광장'으로  변신한 중고거래앱
# newscomname : 뉴스1
# newstitle : '구미 3세 여아' 친모·큰딸 모두 외도?.."나올 수 없는 혈액형"
# newscomname : 머니투데이
# newstitle : [사건의 재구성]"미안  형편 어려워.." 혼수상태 아내 호흡기 뗀 남편
# newscomname : 뉴스1
# newstitle : 오세훈 "중증치매 환자..대통령에게 그 정도 말도 못하나"
# newscomname : 연합뉴스
# newstitle : '혈액형에서 단서 찾았다'..구미 여아 사건 실마리 풀리나
# newscomname : KBS
# newstitle : "전생에 우린 연인 관계였다"..친딸 성폭행한 아빠 '징역 13년'
# newscomname : 이데일리
# newstitle : "美인도·태평양사령부  日요구에 '동해' 표기 정정"<교도>
# newscomname : 연합뉴스
# newstitle : [시선집중] 이상돈 "안철수 도움보다 피곤하게 할 거라는 걸 김종인도 아는 것"
# newscomname : MBC
# newstitle : 입원중인 이재용 부회장  1인실서 4명의 순환감시..국가가 부담하나
# newscomname : 이데일리
# newstitle : 석달 밀린 월급 달랬더니 기름 뿌린 9만 1500개의 동전 집 앞에
# newscomname : 서울신문
# newstitle : [특파원 시선] 1988년 서울올림픽 엠블럼이 이탈리아 주유소에?
# newscomname : 연합뉴스
# newstitle : [단독] 박형준 정무수석 시절 국정원 '사찰 문건' 원문 공개 ②
# newscomname : MBC
# newstitle : "순두부찌개 맛없어 밥값 못준다" 난동..벌금 800만원
# newscomname : 뉴시스
# newstitle : 바이든  中에 재차 경고.."내 눈앞에서 세계 최강국 되는 일 없을 것"
# newscomname : 뉴스1
# newstitle : 대통령 백신 바꿔치기 의혹 "청맹과니나 하는 짓"
# newscomname : 미디어오늘
# newstitle : '바닥 민심'에 안 꽂히는 오세훈 내곡동 총공세  왜?
# newscomname : 한국일보
# newstitle : 삼성중  컨선 20척 2조8천억원에 수주..단일계약으론 세계 최대
# newscomname : 연합뉴스
# newstitle : "백반 한 끼 1000원 식당주인..지갑은 적자  마음은 부자"
# newscomname : 노컷뉴스
# newstitle : 호주  대중국 건초 수출 제동..부메랑 맞은 중국
# newscomname : 아시아경제
# newstitle : 정 총리 "현행 거리두기 2주 연장..5인 모임 금지도 유지"
# newscomname : 뉴시스
# newstitle : "서당 보낸 딸  악마보다 더한 폭행·성적 고문에 엉망됐다..제발"
# newscomname : 머니투데이
# newstitle : 부산어시장에 등장한 '바다의 로또' 참다랑어 2천마리
# newscomname : 연합뉴스
# newstitle : 김종인 "윤석열  별의순간 포착..잘 준비하면 진짜 별 딴다"
# newscomname : 연합뉴스
# newstitle : "합석 거부하자 음식 기다리던 중 쫓겨났습니다" [지금e슈]
# newscomname : 데일리안
# newstitle : '생파 5번' 남양주시장에.."월급이 부끄럽다" 대신 사과한 공무원
# newscomname : 머니투데이
# newstitle : "미혼동료가 유부남과 호텔 들어가더라"..허위사실 40대 남성 집유
# newscomname : 뉴스1
# newstitle : 평균 연봉 1억원 시대?..웃지못하는 은행권
# newscomname : 디지털타임스
# newstitle : "DNA 나왔으면 할 수 없네요" 이춘재도 DNA로 잡았다
# newscomname : 머니투데이
# newstitle : 오세훈이 박영선 앞서자 親文 "요즘 20대는 철이 없어서.."
# newscomname : 조선일보
# newstitle : 구미 친모와 큰딸 '바꿔치기' 공모했나..또 반전
# newscomname : 노컷뉴스
# newstitle : 미인대회 출전 미스 미얀마  국제사회에 "우리 국민 도와주세요"
# newscomname : 연합뉴스
# newstitle : 아시나요? 동백꽃은 세 번 핍니다
# newscomname : 오마이뉴스
# newstitle : 국민의힘 "안철수 개별입당" vs 국민의당 "합당"..물밑 '기싸움'
# newscomname : 헤럴드경제
# newstitle : 노원구 아파트서 세 모녀 피살.. 20대 피의자 현장서 자해
# newscomname : 조선일보
# newstitle : "기부받은 10억 다시 기부"..美 증오범죄 피해 할머니의 결심
# newscomname : 서울신문
# newstitle : '생후 20일 아기를 거꾸로'.. 산후도우미 학대 폭로글 등장
# newscomname : 파이낸셜뉴스
# newstitle : [영상] '여기 도와주세요!' 트럭 세워 주인 살린 반려견
# newscomname : SBS
# newstitle : 식약처  수입 프로바이오틱스 제품 4건 '부적합'..회수 조치
# newscomname : 연합뉴스
# newstitle : 유령도시로 변한 산티아고..칠레  초강력 코로나 봉쇄령 발동
# newscomname : 서울신문
# newstitle : [현장영상] "2주간 현행 거리두기 단계·5인 이상 모임 금지 유지"
# newscomname : YTN
# newstitle : 군에 끌려간 12만명이 굶어죽고 얼어죽었다
# newscomname : 프레시안
# newstitle : 文 34% 최저치 경신  40대도 흔들..민주당 32% 동반 최저(종합)
# newscomname : 뉴스1
# newstitle : [술 취한 의사들 ①] "점심에 소주 반 병  응급실서 와인 진료"..병원 특유의 폐쇄성으로 그저 '쉬쉬'
# newscomname : 데일리안
